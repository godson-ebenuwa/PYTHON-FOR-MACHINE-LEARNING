# %%
#importing modules needed
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV

# %%
dataset = pd.read_csv('C:/Users/godso/Desktop/my_csv/Data_UCI.csv')
dataset
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
#checking for null values
dataset.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
dataset.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
#dropping the stab column
data = dataset.drop(['stab'], axis = 1)
data
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# ...

# %%
#converting to binary labels
binn = LabelEncoder()
data['stabf']= binn.fit_transform(data['stabf'])
data
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4  stabf
# ...

# %%
#splitting our data into train and test 
train_data= data.drop(['stabf'], axis = 1)
y = data['stabf']
x_train, x_test, y_train, y_test = train_test_split(train_data, y, test_size = .2, random_state = 1
                                                   )

# %%
#random forest classifier
rfc= RandomForestClassifier(random_state = 1)
rfc.fit(x_train,y_train)
predicted_values = rfc.predict(x_test)
predicted_values
accuracyy = accuracy_score(y_true=y_test, y_pred=predicted_values) 
print( 'Accuracy: {}' .format(round(accuracy* 100 ), 2 ))
# Out:
# Accuracy: 94

# %%
#extra tree classifier
etc= ExtraTreesClassifier(random_state = 1)
etc.fit(x_train,y_train)
pred_values2 = etc.predict(x_test)
pred_values2
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
#training with xgbboost
xgb_reg = xgb.XGBClassifier(random_state=1)
xgb_reg.fit(x_train, y_train)
pred_values3 = xgb_reg.predict(x_test)
accuracyy = accuracy_score(y_true=y_test, y_pred=pred_values3) 
print( 'Accuracy: {}' .format(round(accuracy* 100 ), 2 ))
# Out:
# c:\users\godso\appdata\local\programs\python\python39\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:08:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 94

# %%
#training with lightgbm
lgb_reg = lgb.LGBMClassifier(random_state= 1)
lgb_reg.fit(x_train, y_train)
pred_values4 = lgb_reg.predict(x_test)
pred_values4
accuracy = accuracy_score(y_true=y_test, y_pred=pred_values4) 
print( 'Accuracy: {}' .format(round(accuracy* 100 ), 2 ))
# Out:
# Accuracy: 94

# %%
rscv= RandomizedSearchCV(estimator =etc,cv=5,n_iter=10,scoring = 'accuracy',n_jobs = -1,verbose = 1, random_state = 1)
rscv.fit(x_train,y_train)
pred_values5 = rscv.predict(x_test)
pred_values5
accuracy5 = accuracy_score(y_true=y_test, y_pred=pred_values5) 
print( 'Accuracy: {}' .format(round(accuracy* 100 ), 2 ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d32dbd368bdc> in <module>
# ----> 1 rscv= RandomizedSearchCV(estimator =etc,cv=5,n_iter=10,scoring = 'accuracy',n_jobs = -1,verbose = 1, random_state = 1)
#       2 rscv.fit(x_train,y_train)
#       3 pred_values5 = rscv.predict(x_test)
#       4 pred_values5
#       5 accuracy5 = accuracy_score(y_true=y_test, y_pred=pred_values5)
#
# TypeError: __init__() missing 1 required positional argument: 'param_distributions'
